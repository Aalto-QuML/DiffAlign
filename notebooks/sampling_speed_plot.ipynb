# %%
sampling_step_counts = [1,2,5,10,20,50,100]
top_1s = [0,0,0,0,0.00390625,0.037109375,0.05078]
top_3s = [0,0,0,0.00390625,0.017578125,0.05859375,0.07226]
top_5s = [0,0,0,0.009765625,0.025390625,0.068359375,0.07812]
top_100s = [0,0,0.001953125,0.01953125,0.064453125,0.142578125,0.1562]

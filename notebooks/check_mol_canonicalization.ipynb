# %%
from rdkit import Chem

# %%
r1 = 'N#CC1=C(F)C=CC=C1C1=CC=CC=C1.NC1CCCCC1'
r2 = 'N#CC1=C(C2=CC=CC=C2)C=CC=C1F.NC1CCCCC1'

# %%
Chem.MolToSmiles(Chem.MolFromSmiles(r1.split('.')[0]))
# Out:
# 'N#Cc1c(F)cccc1-c1ccccc1'

# %%
Chem.MolToSmiles(Chem.MolFromSmiles(r2.split('.')[0]))
# Out:
# 'N#Cc1c(F)cccc1-c1ccccc1'

# %%
sm = 'O=C1C2=CC(Br)=CC=C2NC1=NO'
Chem.MolToSmiles(Chem.MolFromSmiles(sm))
# Out:
# 'O=C1C(=NO)Nc2ccc(Br)cc21'
